# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score as score

# %%
train = pd.read_csv("C:/Users/Acer/Desktop/Kaggle/Santander/train.csv")
test = pd.read_csv("C:/Users/Acer/Desktop/Kaggle/Santander/test.csv")

# %%
train.tail()
# Out:
#              ID_code  target    var_0   var_1    var_2   var_3    var_4  \
# 199995  train_199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404
# 199996  train_199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096
# 199997  train_199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410
# 199998  train_199998       0   9.7148 -8.6098  13.6104  5.7930  12.5173
# 199999  train_199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577
#
#           var_5   var_6    var_7  ...  var_190  var_191  var_192  var_193  \
# 199995  11.6081  5.6709  15.1516  ...   6.1415  13.2305   3.9901   0.9388
# 199996 -10.5628  5.8802  21.5940  ...   4.9611   4.6549   0.6998   1.8341
# 199997  -5.4086  4.5555  21.5571  ...   4.0651   5.4414   3.1032   4.8793
# 199998   0.5339  6.0479  17.0152  ...   2.6840   8.6587   2.7337  11.1178
# 199999   0.3488  5.2839  15.2058  ...   8.9842   1.6893   0.1276   0.3766
#
#         var_194  var_195  var_196  var_197  var_198  var_199
# ...

# %% [markdown]
# #### Experiment - let me try using merely 10 random variables for prediction.

# %%
train = train.drop('ID_code', axis =1 )
test = test.drop('ID_code', axis =1)

# %%
X_train = train.drop('target',  axis =1)
y_train = train['target']

X_test = test

# %%
X_train
# Out:
#           var_0   var_1    var_2   var_3    var_4    var_5   var_6    var_7  \
# 0        8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834  5.1187  18.6266
# 1       11.5006 -4.1473  13.8588  5.3890  12.3622   7.0433  5.6208  16.5338
# 2        8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427  14.6155
# 3       11.0604 -2.1518   8.9522  7.1957  12.5846  -1.8361  5.8428  14.9250
# 4        9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486  5.9405  19.2514
# ...         ...     ...      ...     ...      ...      ...     ...      ...
# 199995  11.4880 -0.4956   8.2622  3.5142  10.3404  11.6081  5.6709  15.1516
# 199996   4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628  5.8802  21.5940
# 199997  11.2232 -5.0518  10.5127  5.6456   9.3410  -5.4086  4.5555  21.5571
# 199998   9.7148 -8.6098  13.6104  5.7930  12.5173   0.5339  6.0479  17.0152
# 199999  10.8762 -5.7105  12.1183  8.0328  11.5577   0.3488  5.2839  15.2058
#
# ...

# %%
col = ['var_199', 'var_100', 'var_95', 'var_69', 'var_54', 'var_112', 'var_157', 'var_75', 'var_29', 'var_82'] ### random subset of 10 variables

# %%
X_train1 = train[col]
X_test1 = test[col]

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train1, y_train)
# Out:
# LogisticRegression()

# %%
y1 = lr.predict(X_train1)

# %%
score(y1, y_train)           ### barely a difference from using all variables which gives me 91% accuracy
# Out:
# 0.89951

# %% [markdown]
# #### Random Forests

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train1, y_train)
# Out:
# RandomForestClassifier()

# %%
y2 = rf.predict(X_train1)

# %%
score(y2, y_train)       ### not bad
# Out:
# 0.99996

# %%
y2 = pd.DataFrame(y2)

# %% [markdown]
# y2 = y2.to_excel('y2_sub.xlsx', index = False)    ### 50% test accuracy - useless

# %% [markdown]
# ## Feature selection - using random forests

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)

# %% [markdown]
# #### Getting features importance

# %%
imp = rf.feature_importances_

# %%
imp_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': imp})

# %%
imp_df

# %%
## Using 0.07 as threshold - just an experiment
imp_features = imp_df[imp_df['Importance'] > 0.007]

# %%
imp_features

# %%
features = imp_features['Feature']

# %%
features = np.array(features)

# %%
features

# %% [markdown]
# ### Using these features to train the model

# %%
X1 = X_train[features]
X2 = test[features]

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X1, y_train)

# %%
y2 = rf.predict(X1)

# %%
score(y2, y_train)     ## will this do any better on the test data? I highly doubt it

# %%
y_test = rf.predict(X2)

# %%
y_test = pd.DataFrame(y_test)

# %%
sub6 = y_test.to_excel('sub6.xlsx', index = False)   ####

# %% [markdown]
# #### Never tried Naive Bayes earlier - let's see

# %%
from sklearn.naive_bayes import GaussianNB
gauss = GaussianNB()

# %%
gauss.fit(X1, y_train)

# %%
y1 = gauss.predict(X1)

# %%
score(y1, y_train)

# %%
# What if I use all features?
gauss = GaussianNB()

# %%
gauss.fit(X_train, y_train)

# %%
y2 = gauss.predict(X_train)

# %%
score(y2 , y_train)         ## better

# %%
y_test = gauss.predict(X_test)

# %%
y_test = pd.DataFrame(y_test)       ### 67% accuracy

# %%
sub7 = y_test.to_excel('sub7.xlsx', index = False)

# %% [markdown]
# ## I am going to edit Naive Bayes - it is giving a decentish result

# %% [markdown]
# #### Naive Bayes assumes that all outcomes are equally likely - based on the train dataset, that is absolutely not the case.

# %%
train['target'].value_counts()

# %%
p0 = 179902/(179902+20098)
p1 = 20098/(179902+20098)

# %%
p1, p0 #### perfect - time to include these in my NB model

# %%
priors1 = np.array([0.89951, 0.10049])

# %%
gauss = GaussianNB(priors = priors1)

# %%
gauss.fit(X_train, y_train)

# %%
y1 = gauss.predict(X_train)

# %%
score(y1, y_train)            ### exact same as before - but will this change the test dataset performance?

# %%
y_test = gauss.predict(X_test)            ### exact same as before

# %%
y_test = pd.DataFrame(y_test)

# %%
y_test.to_excel('sub8.xlsx', index = False)

# %% [markdown]
# ### Let me try reducing overfitting in Naive Bayes

# %%
### I am doing that in a notebook titled Santander 4
